# %%
import pandas as pd

# %%
disaster = pd.read_csv("train.csv")

# %%
disaster
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
disaster.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
y = disaster["Survived"]

# %%
x = disaster.drop(["Cabin","Name","Ticket"],axis=1)

# %%
x
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
import numpy as np

# %%
x["Age"].fillna(np.mean(x["Age"]),inplace=True)

# %%
x.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
x.dropna(inplace=True)

# %%
x.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
x
# Out:
#      PassengerId  Survived  Pclass     Sex        Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.000000      1      0   7.2500
# 1              2         1       1  female  38.000000      1      0  71.2833
# 2              3         1       3  female  26.000000      0      0   7.9250
# 3              4         1       1  female  35.000000      1      0  53.1000
# 4              5         0       3    male  35.000000      0      0   8.0500
# ..           ...       ...     ...     ...        ...    ...    ...      ...
# 886          887         0       2    male  27.000000      0      0  13.0000
# 887          888         1       1  female  19.000000      0      0  30.0000
# 888          889         0       3  female  29.699118      1      2  23.4500
# 889          890         1       1    male  26.000000      0      0  30.0000
# 890          891         0       3    male  32.000000      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# ...

# %%
dummies1 = pd.get_dummies(x[["Sex","Fare","Embarked"]])

# %%
dummies1
# Out:
#         Fare  Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0     7.2500           0         1           0           0           1
# 1    71.2833           1         0           1           0           0
# 2     7.9250           1         0           0           0           1
# 3    53.1000           1         0           0           0           1
# 4     8.0500           0         1           0           0           1
# ..       ...         ...       ...         ...         ...         ...
# 886  13.0000           0         1           0           0           1
# 887  30.0000           1         0           0           0           1
# 888  23.4500           1         0           0           0           1
# 889  30.0000           0         1           1           0           0
# 890   7.7500           0         1           0           1           0
#
# [889 rows x 6 columns]

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
catergorical_features =  ["Sex","Fare","Embarked"]
one_hot = OneHotEncoder()

# %%
transformer = ColumnTransformer([("one_hot",one_hot,catergorical_features)],remainder="passthrough")

# %%
transformed_X = transformer.fit_transform(x)

# %%
transformed_X
# Out:
# <889x258 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6170 stored elements in Compressed Sparse Row format>

# %%
new_x = pd.DataFrame(transformed_X)

# %%
new_x
# Out:
#                                                      0
# 0      (0, 1)\t1.0\n  (0, 20)\t1.0\n  (0, 251)\t1.0...
# 1      (0, 0)\t1.0\n  (0, 209)\t1.0\n  (0, 249)\t1....
# 2      (0, 0)\t1.0\n  (0, 43)\t1.0\n  (0, 251)\t1.0...
# 3      (0, 0)\t1.0\n  (0, 191)\t1.0\n  (0, 251)\t1....
# 4      (0, 1)\t1.0\n  (0, 45)\t1.0\n  (0, 251)\t1.0...
# ..                                                 ...
# 884    (0, 1)\t1.0\n  (0, 87)\t1.0\n  (0, 251)\t1.0...
# 885    (0, 0)\t1.0\n  (0, 155)\t1.0\n  (0, 251)\t1....
# 886    (0, 0)\t1.0\n  (0, 133)\t1.0\n  (0, 251)\t1....
# 887    (0, 1)\t1.0\n  (0, 155)\t1.0\n  (0, 249)\t1....
# 888    (0, 1)\t1.0\n  (0, 32)\t1.0\n  (0, 250)\t1.0...
#
# [889 rows x 1 columns]

# %%
dummies = pd.get_dummies(x[["Sex","Fare","Embarked","Pclass","PassengerId","SibSp","Parch","Survived","Age"]])

# %%
dummies
# Out:
#         Fare  Pclass  PassengerId  SibSp  Parch  Survived        Age  \
# 0     7.2500       3            1      1      0         0  22.000000
# 1    71.2833       1            2      1      0         1  38.000000
# 2     7.9250       3            3      0      0         1  26.000000
# 3    53.1000       1            4      1      0         1  35.000000
# 4     8.0500       3            5      0      0         0  35.000000
# ..       ...     ...          ...    ...    ...       ...        ...
# 886  13.0000       2          887      0      0         0  27.000000
# 887  30.0000       1          888      0      0         1  19.000000
# 888  23.4500       3          889      1      2         0  29.699118
# 889  30.0000       1          890      0      0         1  26.000000
# 890   7.7500       3          891      0      0         0  32.000000
#
#      Sex_female  Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0             0         1           0           0           1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y = dummies["Survived"]

# %%
clf = RandomForestClassifier(n_estimators =2000)
dummies.drop("Survived",axis=1,inplace=True)

# %%
clf.fit(dummies,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=2000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test = pd.read_csv("test.csv")

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.drop(["Name","Ticket","Cabin"],axis=1)
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0            892       3    male  34.5      0      0    7.8292        Q
# 1            893       3  female  47.0      1      0    7.0000        S
# 2            894       2    male  62.0      0      0    9.6875        Q
# 3            895       3    male  27.0      0      0    8.6625        S
# 4            896       3  female  22.0      1      1   12.2875        S
# ..           ...     ...     ...   ...    ...    ...       ...      ...
# 413         1305       3    male   NaN      0      0    8.0500        S
# 414         1306       1  female  39.0      0      0  108.9000        C
# 415         1307       3    male  38.5      0      0    7.2500        S
# 416         1308       3    male   NaN      0      0    8.0500        S
# 417         1309       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
x_test = pd.get_dummies(test[["Sex","Fare","Embarked","Pclass","PassengerId","SibSp","Parch","Age"]])

# %%
x_test
# Out:
#          Fare  Pclass  PassengerId  SibSp  Parch   Age  Sex_female  Sex_male  \
# 0      7.8292       3          892      0      0  34.5           0         1
# 1      7.0000       3          893      1      0  47.0           1         0
# 2      9.6875       2          894      0      0  62.0           0         1
# 3      8.6625       3          895      0      0  27.0           0         1
# 4     12.2875       3          896      1      1  22.0           1         0
# ..        ...     ...          ...    ...    ...   ...         ...       ...
# 413    8.0500       3         1305      0      0   NaN           0         1
# 414  108.9000       1         1306      0      0  39.0           1         0
# 415    7.2500       3         1307      0      0  38.5           0         1
# 416    8.0500       3         1308      0      0   NaN           0         1
# 417   22.3583       3         1309      1      1   NaN           0         1
#
#      Embarked_C  Embarked_Q  Embarked_S
# ...

# %%
x_test.isna().sum()
# Out:
# Fare            1
# Pclass          0
# PassengerId     0
# SibSp           0
# Parch           0
# Age            86
# Sex_female      0
# Sex_male        0
# Embarked_C      0
# Embarked_Q      0
# Embarked_S      0
# dtype: int64

# %%
x_test["Age"].fillna(np.mean(x_test["Age"]),inplace=True)
x_test["Fare"].fillna(np.mean(x_test["Fare"]),inplace=True)
x_test
x_test.isna().sum()
# Out:
# Fare           0
# Pclass         0
# PassengerId    0
# SibSp          0
# Parch          0
# Age            0
# Sex_female     0
# Sex_male       0
# Embarked_C     0
# Embarked_Q     0
# Embarked_S     0
# dtype: int64

# %%
results = clf.predict(x_test)

# %% [markdown]
# ## Fare	Pclass	PassengerId	SibSp	Parch	Sex_female	Sex_male	Embarked_C	Embarked_Q	Embarked_S
#
# ## Fare	Pclass	PassengerId	SibSp	Parch	Sex_female	Sex_male	Embarked_C	Embarked_Q	Embarked_S

# %%
result = pd.DataFrame({"PassengerId" : x_test["PassengerId"],"Survived":results})

# %%
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
result.to_csv("results7.csv",index=False)

# %%
result
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
hello = pd.read_csv("results6.csv")

# %%
hello
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         0
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(dummies,y)

# %%
classifier = RandomForestClassifier()

# %%
classifier.get_params()
# Out:
# {'bootstrap': True,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 'warn',
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid = {'n_estimators':[10,100,200,500,1000,1200],
       'max_depth':[None,5,10,20,30],
       'max_features':['auto','sqrt'],
       'mic_samples_split':[2,4,6],
       'min_samples_leaf':[1,2,4]}
